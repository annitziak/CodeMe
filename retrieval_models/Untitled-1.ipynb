# %%
import math
from collections import defaultdict
import pandas as pd

def preprocess_query(query: str) -> list:
    """
    Preprocess the input query.
    This is a placeholder for more advanced preprocessing.
    """
    # Convert to lowercase and tokenize
    return query.lower().split()

def query_expansion(preprocessed_query: list) -> list:
    """
    TO DO TOMORROW : EMBEDDINGS ETC
    Expand the query with synonyms or related terms.
    This is a placeholder for more advanced query expansion techniques.
    """
    return preprocessed_query

def compute_bm25(token, index, doc_lengths, avg_doc_length, total_docs, k1=1.5, b=0.75):
    """
    Compute BM25 score for each token over all documents in which it appears.

    Args:
        token (str): token
        index (dict): inverted index
        doc_lengths (dict): dictionary of document lengths
        avg_doc_length (float): average document length in the corpus.
        total_docs (int): number of documents in the corpus.
        k1 (float): term saturation.
        b (float): length normalization.

    Returns:
        dict: A dictionary with document numbers as keys and BM25 scores as values.
    """
    if token not in index:
        return {}  # Token not in the index

    df = index[token]['df']  # doc frequency
    idf = math.log((total_docs - df + 0.5) / (df + 0.5) + 1)  # idf calculation

    scores = {}
    for docno, positions in index[token]['doc_info'].items():
        freq = len(positions)  # frequency is len of positions list
        doc_length = doc_lengths.get(docno, 0) #get the length of doc
        term_freq_component = freq * (k1 + 1) / (freq + k1 * (1 - b + b * (doc_length / avg_doc_length))) #the second component of formula
        scores[docno] = idf * term_freq_component

    return scores

def retrieval_function(query, index, doc_lengths, k1=1.5, b=0.75):
    """
    Retrieve documents based on a query using the BM25 scoring function.

    Args:
        query (str): The user query as a string.
        index (dict): The inverted index structure.
        doc_lengths (dict): A dictionary of document lengths ({docno: length}).
        k1 (float): BM25 hyperparameter for term saturation.
        b (float): BM25 hyperparameter for length normalization.

    Returns:
        list: A list of tuples (docno, score) sorted by descending score.
    """
    # Preprocess the query
    tokens = preprocess_query(query)  # returns a list of tokens

    # Calculate average document length
    total_docs = len(doc_lengths)
    avg_doc_length = sum(doc_lengths.values()) / total_docs if total_docs > 0 else 0

    # aggregate scores for all tokens in the query
    aggregated_scores = defaultdict(float)
    for token in tokens:
        token_scores = compute_bm25(token, index, doc_lengths, avg_doc_length, total_docs, k1, b)
        for docno, score in token_scores.items():
            aggregated_scores[docno] += score

    # Sort documents by score in descending order and return the top results
    #return only the first 100 - but we do have to calculate for all of them probably
    return sorted(aggregated_scores.items(), key=lambda x: x[1], reverse=True)[:100]

# %%
query = "example query"

    # Perform retrieval
results = retrieval_function(query, inverted_index_positions, doc_lengths)

    # Print results
print("Top Results:", results)

# %%
#first option is to embed all the words anyway using this model and then extract the embeddings for the query
#this takes very long
"""
from transformers import AutoTokenizer, AutoModel
import torch
tokenizer = AutoTokenizer.from_pretrained("microsoft/codebert-base")
model = AutoModel.from_pretrained("microsoft/codebert-base") 
"""
from transformers import AutoTokenizer, AutoModel
import torch
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load a large language model (e.g., GPT-2 or GPT-3-like model)

# we can also explore co-occurence models etc? -> but then we need to store the bm25 table in memory
tokenizer = AutoTokenizer.from_pretrained("microsoft/codebert-base")
model = AutoModel.from_pretrained("microsoft/codebert-base")

import numpy as np
from tqdm import tqdm  # For progress visualization

# Function to compute embeddings for a batch of words
def get_embeddings_batch(words):
    inputs = tokenizer(words, return_tensors="pt", padding=True, truncation=True)
    outputs = model(**inputs)
    # Take the mean of the hidden states for each word in the batch
    return outputs.last_hidden_state.mean(dim=1).detach().numpy()

# Precompute embeddings for the vocabulary in batches
def precompute_vocab_embeddings(vocab, batch_size=32):
    embeddings = []
    word_list = list(vocab)
    total_words = len(word_list)

    for i in tqdm(range(0, total_words, batch_size), desc="Processing batches"):
        batch_words = word_list[i:i + batch_size]
        try:
            batch_embeddings = get_embeddings_batch(batch_words)
            embeddings.append(batch_embeddings)
        except Exception as e:
            print(f"Failed to compute embeddings for batch: {batch_words}, error: {e}")

    # Stack all embeddings into a single numpy array
    return np.vstack(embeddings), word_list

# Assuming `vocab` is a set or list of words
vocab = inverted_index_positions.keys()  # Get vocabulary from the inverted index
vocab_embeddings, word_list = precompute_vocab_embeddings(vocab, batch_size=100)
# Out:
# c:\Users\annie\anaconda3\anaconda\Lib\site-packages\transformers\modeling_utils.py:479: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(checkpoint_file, map_location=map_location)
# Processing batches: 100%|██████████| 14/14 [00:12<00:00,  1.13it/s]

# %%
#make embeddings for the vocabulary
from transformers import AutoTokenizer, AutoModel
import torch
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm  # For progress visualization

from data_loaders import *

class EmbeddingModel:
    def __init__(self, vocab:list, model_name="microsoft/codebert-base"):
        """
        Initialize the EmbeddingModel with the specified vocabulary and model.
        Args:
            vocab (list or set): A list or set of vocabulary words.
            model_name (str): The name of the pretrained model to load.
        """
        # Initialize and load tokenizer and model
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.model = AutoModel.from_pretrained(model_name)
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model = self.model.to(self.device)
        self.vocab = vocab  # Store vocab as a list for processing

        #precompute embeddings for the vocabulary in batches
        self.embeddings = self.precompute_vocab_embeddings(batch_size = 100)


    def get_embeddings_batch(self, words):
        """
        Computes embeddings for a batch of words.
        Args:
            words (list): A batch of words.
        Returns:
            np.ndarray: A 2D array of embeddings for the input words.
        """
        # Tokenize the input words
        inputs = self.tokenizer(words, return_tensors="pt", padding=True, truncation=True).to(self.device)
        with torch.no_grad():
            outputs = self.model(**inputs)
        # Return the mean-pooled embeddings
        return outputs.last_hidden_state.mean(dim=1).cpu().numpy()

    def precompute_vocab_embeddings(self, batch_size=50):
        """
        Precomputes embeddings for all words in the vocabulary using batching.
        Args:
            batch_size (int): The size of each batch for processing.
        Returns:
            np.ndarray: A 2D array of word embeddings.
            list: A list of words corresponding to the embeddings.
        """
        embeddings = []
        total_words = len(self.vocab)

        for i in tqdm(range(0, total_words, batch_size), desc="Processing batches"):
            batch_words = self.vocab[i:i + batch_size]
            try:
                batch_embeddings = self.get_embeddings_batch(batch_words)
                embeddings.append(batch_embeddings)
            except Exception as e:
                print(f"Failed to compute embeddings for batch: {batch_words}, error: {e}")

        return np.vstack(embeddings)
    
    def get_embedding(self, word):
        """
        Computes the embedding for a single word.
        Args:
            word (str): The input word.
        Returns:
            np.ndarray: The embedding of the input word.
        """
        embedding = self.get_embeddings_batch([word])
        return embedding

    def find_similar_words(self, word, top_k=5):
        """
        Finds the top_k most similar words to the given word using cosine similarity
        Args:
            word (str): The target word.
            vocab_embeddings (np.ndarray): The precomputed embeddings of the vocabulary.
            word_list (list): The vocabulary list corresponding to the embeddings.
            top_k (int): The number of similar words to return.
        Returns:
            list: A list of tuples containing similar words and their cosine similarities.
        """
        target_embedding = self.get_embedding(word)
        # Compute cosine similarity in a vectorized manner
        similarities = cosine_similarity(target_embedding, self.embeddings)[0]
        # Get the top_k most similar words
        top_indices = np.argsort(similarities)[::-1][:top_k]

        #return the top similar words
        return [self.vocab[i] for i in top_indices]


# Example usage
if __name__ == "__main__":
    # Example vocabulary
    inverted_index_positions = Index() # this is preloaded data for now
    vocab = inverted_index_positions.vocab

    # Initialize the model
    embedding_model = EmbeddingModel(vocab)  #this will also precompute all the embeddings

    #experimenting to see similarities
    experiment_words = vocab[100:110]
    for experiment_word in experiment_words:
        print(experiment_word, embedding_model.find_similar_words(experiment_word))
# Out:
# Skipping invalid term line: ::3939
# Skipping invalid term line: http://.:1
# Skipping invalid term line: http://.appspot.com/static/css/foo.css,:1
# Skipping invalid term line: http://3v4l.org/VC93o:1
# Skipping invalid term line: http://72dpi.nl/klanten/makelaarsland/team/:1
# Skipping invalid term line: http://activemq.apache.org/should-i-use-transactions.html:1
# Skipping invalid term line: http://adit.io/posts/2013-04-17-functors,_applicatives,_and_monads_in_pictures.html:1
# Skipping invalid term line: http://adodson.com/hello.js/#helloapi:1
# Skipping invalid term line: http://adodson.com/hello.js/#oauth-proxy:1
# Skipping invalid term line: http://advancedlinuxprogramming.com/:1
# Skipping invalid term line: http://afgomez.es/blog/better-ajax-callbacks-with-jquery-promises/:1
# Skipping invalid term line: http://agency.lastminute-hr.com/stranice/upisi_destinacije_unico.php:1
# Skipping invalid term line: http://ajax.googleapis.com/ajax/libs/angularjs/1.2.26/angular-route.min.js:1
# Skipping invalid term line: http://algoviz.org/OpenDSA/Books/OpenDSA/html/HashCImproved.html#HashingPseudoRandomProbePRO:1
# Skipping invalid term line: http://alistapart.com/article/creating-intrinsic-ratios-for-video/:1
# Skipping invalid term line: http://altbeacon.github.io/android-beacon-library/samples.html:1
# Skipping invalid term line: http://andreareginato.github.io/oauth-ng/:1
# Skipping invalid term line: http://andrewjwelch.com/lexev/:1
# Skipping invalid term line: http://android-developers.blogspot.com/2014/10/appcompat-v21-material-design-for-pre.html:1
# Skipping invalid term line: http://android-developers.blogspot.in/2011/09/androids-http-clients.html:1
# Skipping invalid term line: http://android-developers.blogspot.nl/2014/10/implementing-material-design-in-your.html:1
# Skipping invalid term line: http://android-er.blogspot.in/2013/10/gridview-example-load-images-to.html:1
# Skipping invalid term line: http://android-holo-colors.com/:1
# Skipping invalid term line: http://angular-ui.github.io/bootstrap/:2
# Skipping invalid term line: http://angular.github.io/protractor/#/api?view=webdriver.WebDriver.prototype.executeAsyncScript:1
# Skipping invalid term line: http://angular.github.io/protractor/#/api?view=webdriver.WebDriver.prototype.executeScript:1
# Skipping invalid term line: http://answers.awesomium.com/questions/2289/can-i-use-userscripts-or-greasemonkey-scripts-in-a.html:1
# Skipping invalid term line: http://answers.microsoft.com/en-us/windows/forum/windows_rt-networking/possible-windows-firewall-bug-on-surface-rt-blocks/caa8b40c-dacc-4d19-a751-7a04f8ef00e4:1
# Skipping invalid term line: http://answers.opencv.org/questions/:1
# Skipping invalid term line: http://ant.apache.org/bindownload.cgi:1
# Skipping invalid term line: http://ant.apache.org/manual/Tasks/import.html:1
# Skipping invalid term line: http://api.jquery.com/append/:1
# Skipping invalid term line: http://api.jquery.com/category/selectors/:1
# Skipping invalid term line: http://api.jquery.com/click/#click-eventData-handler:1
# Skipping invalid term line: http://api.jquery.com/clone/:1
# Skipping invalid term line: http://api.jquery.com/empty/:1
# Skipping invalid term line: http://api.jquery.com/eq/:1
# Skipping invalid term line: http://api.jquery.com/get/:1
# Skipping invalid term line: http://api.jquery.com/hidden-selector/:1
# Skipping invalid term line: http://api.jquery.com/html/:1
# Skipping invalid term line: http://api.jquery.com/jQuery.each/:1
# Skipping invalid term line: http://api.jquery.com/jQuery.when/:1
# Skipping invalid term line: http://api.jquery.com/jQuery/:1
# Skipping invalid term line: http://api.jquery.com/jQuery/#jQuery-html-attributes:1
# Skipping invalid term line: http://api.jquery.com/jquery.ajax/:1
# Skipping invalid term line: http://api.jquery.com/jquery.each/:1
# Skipping invalid term line: http://api.jquery.com/jquery.map/:1
# Skipping invalid term line: http://api.jquery.com/load/:2
# Skipping invalid term line: http://api.jquery.com/lt-selector/:1
# Skipping invalid term line: http://api.jquery.com/on/:2
# Skipping invalid term line: http://api.jquery.com/prepend/:1
# Skipping invalid term line: http://api.jquery.com/prevall/:1
# Skipping invalid term line: http://api.jquery.com/visible-selector/:1
# Skipping invalid term line: http://api.rubyonrails.org/classes/ActiveRecord/Associations/ClassMethods.html#label-Bi-directional+associations:1
# Skipping invalid term line: http://api.soundcloud.com/tracks.json?client_id=4346c8125f4f5c40ad666bacd8e96498&q=tere%20bin&limit=1:1
# Skipping invalid term line: http://apidock.com/ruby/Enumerable/each_slice:1
# Skipping invalid term line: http://aws.amazon.com/blogs/aws/dynamodb-update-json-and-more/:1
# Skipping invalid term line: http://azure.microsoft.com/en-us/documentation/articles/documentdb-limits/:1
# Skipping invalid term line: http://azure.microsoft.com/en-us/documentation/articles/virtual-machines-linux-use-ssh-key/:1
# Skipping invalid term line: http://azure.microsoft.com/en-us/documentation/articles/websites-dotnet-deploy-webjobs/:1
# Skipping invalid term line: http://badgerfish.ning.com/:1
# Skipping invalid term line: http://bahmutov.calepin.co/why-promises-need-to-be-done.html:1
# Skipping invalid term line: http://bauer-dev.windmilldesignworks.com/:1
# Skipping invalid term line: http://bazaar.launchpad.net/~richard-p7/nfcpy/pcsc/view/head:/nfc/dev/pn53x.py#L615:1
# Skipping invalid term line: http://beanvalidation.org/1.0/spec/#constraintsdefinitionimplementation-validationimplementation:1
# Skipping invalid term line: http://behat.readthedocs.org/en/v2.5/guides/1.gherkin.html:1
# Skipping invalid term line: http://benfrain.com/when-and-where-you-can-use-numbers-in-id-and-class-names/:1
# Skipping invalid term line: http://beta.sportsdirect.bg/test/:1
# Skipping invalid term line: http://bigflake.com/mediacodec/:1
# Skipping invalid term line: http://bildr.org/2012/04/tb6612fng-arduino/:1
# Skipping invalid term line: http://binodmahto.blogspot.in/2013/03/all-about-jsonobject.html:1
# Skipping invalid term line: http://bitoftech.net/2014/06/01/token-based-authentication-asp-net-web-api-2-owin-asp-net-identity/:2
# Skipping invalid term line: http://bitsnoop.com/api/trackers.php?hash=98C5C361D0BE5F2A07EA8FA5052E5AA48097E7F6&json=1:1
# Skipping invalid term line: http://bitwiseshiftleft.github.io/sjcl/:1
# Skipping invalid term line: http://bl.ocks.org/mbostock/3680957:1
# Skipping invalid term line: http://bl.ocks.org/mbostock/3680999:1
# Skipping invalid term line: http://bl.ocks.org/mbostock/7280327:1
# Skipping invalid term line: http://bl.ocks.org/mbostock/7882658:1
# Skipping invalid term line: http://bl.ocks.org/nilanjenator/4950148:1
# Skipping invalid term line: http://blazemeter.com/blog/how-use-jmeter-functions-part-iii:1
# Skipping invalid term line: http://blazemeter.com/blog/using-jmeters-http-header-manager:1
# Skipping invalid term line: http://blog.3960.org/:1
# Skipping invalid term line: http://blog.bdoughan.com/2010/08/jaxb-namespaces.html:1
# Skipping invalid term line: http://blog.bdoughan.com/2011/05/specifying-eclipselink-moxy-as-your.html:1
# Skipping invalid term line: http://blog.bitbucket.org/2013/09/16/take-control-with-branch-restrictions/:1
# Skipping invalid term line: http://blog.brunoscopelliti.com/deal-with-users-authentication-in-an-angularjs-web-app:1
# Skipping invalid term line: http://blog.chapagain.com.np/magento-quick-way-to-create-order-invoice-programmatically/:1
# Skipping invalid term line: http://blog.codinghorror.com/learn-to-read-the-source-luke/:1
# Skipping invalid term line: http://blog.encoresystems.net/articles/how-to-capture-soap-envelopes-when-consuming-a-web-service.aspx:1
# Skipping invalid term line: http://blog.getpelican.com/:1
# Skipping invalid term line: http://blog.izs.me/post/2353458699/an-open-letter-to-javascript-leaders-regarding:1
# Skipping invalid term line: http://blog.jetbrains.com/webstorm/2014/09/meteor-support-in-webstorm-9/:1
# Skipping invalid term line: http://blog.jooq.org/2014/06/13/java-8-friday-10-subtle-mistakes-when-using-the-streams-api/:1
# Skipping invalid term line: http://blog.ltgt.net/gwt-21-activities-nesting-yagni/:1
# Skipping invalid term line: http://blog.mailchimp.com/is-your-own-domain-name-getting-you-blocked/:1
# Skipping invalid term line: http://blog.miguelgrinberg.com/post/the-flask-mega-tutorial-part-v-user-logins:1
# Skipping invalid term line: http://blog.notdot.net/2010/04/Using-the-new-bulkloader:1
# Skipping invalid term line: http://blog.nraboy.com/2014/09/create-an-rss-reader-using-angularjs-and-ionicframework/:1
# Skipping invalid term line: http://blog.petegoo.com/Pushqa/:1
# Skipping invalid term line: http://blog.ploeh.dk/2011/07/28/CompositionRoot/:1
# Skipping invalid term line: http://blog.ploeh.dk/2012/10/03/DependencyInjectioninASP.NETWebAPIwithCastleWindsor/:1
# Skipping invalid term line: http://blog.ploeh.dk/archive.html:1
# Skipping invalid term line: http://blog.podsnap.com/ducers2.html:1
# Skipping invalid term line: http://blog.sqlauthority.com/2009/05/18/sql-server-fix-management-studio-error-saving-changes-in-not-permitted-the-changes-you-have-made-require-the-following-tables-to-be-dropped-and-re-created-you-have-either-made-changes-to-a-tab/:1
# Skipping invalid term line: http://blog.yodersolutions.com/angularjs-count-the-number-of-watchers-on-a-page/:1
# Skipping invalid term line: http://blogs.aws.amazon.com/security/post/Tx70F69I9G8TYG/How-to-enable-cross-account-access-to-the-AWS-Management-Console:1
# Skipping invalid term line: http://blogs.msdn.com/b/axsupport/archive/2012/11/20/quot-parameter-is-missing-a-value-quot-error-running-a-customized-report-in-microsoft-dynamics-ax-2012.aspx:1
# Skipping invalid term line: http://blogs.msdn.com/b/carlosfigueira/archive/2012/10/25/getting-user-information-on-azure-mobile-services.aspx:1
# Skipping invalid term line: http://blogs.msdn.com/b/ericlippert/archive/2003/09/17/53038.aspx:1
# Skipping invalid term line: http://blogs.msdn.com/b/ericlippert/archive/2009/11/12/closing-over-the-loop-variable-considered-harmful.aspx:1
# Skipping invalid term line: http://blogs.msdn.com/b/ericwhite/archive/2008/09/29/the-flat-opc-format.aspx:1
# Skipping invalid term line: http://blogs.technet.com/b/heyscriptingguy/archive/2010/11/09/using-powershell-get-member-to-explore-the-net-framework.aspx:1
# Skipping invalid term line: http://blogs.technet.com/b/heyscriptingguy/archive/2011/03/21/use-powershell-to-replace-text-in-strings.aspx:1
# Skipping invalid term line: http://blogs.technet.com/b/learningittogether/archive/2014/10/27/using-rest-api-from-powershell-to-get-additional-azure-vm-status-details.aspx:1
# Skipping invalid term line: http://bluebeetlezar.tumblr.com/image/101630187766:1
# Skipping invalid term line: http://bluegriffon.org/public/info/svg.png:1
# Skipping invalid term line: http://bobby-tables.com:1
# Skipping invalid term line: http://boofcv.org/index.php?title=Example_Fit_Ellipse:1
# Skipping invalid term line: http://boofcv.org/index.php?title=Example_Fit_Polygon:1
# Skipping invalid term line: http://books.google.pl/books?id=iilIj3JXNrAC&printsec=frontcover&hl=pl&source=gbs_ge_summary_r&cad=0#v=onepage&q&f=false:1
# Skipping invalid term line: http://bootdey.com/snippets/view/Bootstrap-Gallery-with-Modal-Lightbox-and-Carousel-114:1
# Skipping invalid term line: http://bootply.com:1
# Skipping invalid term line: http://bootstrapcdn.com/#fontawesome_tab:1
# Skipping invalid term line: http://bootstrapcdn.com/#quickstart_tab:1
# Skipping invalid term line: http://bootstrapvalidator.com/settings/#events:1
# Skipping invalid term line: http://bower.io/:1
# Skipping invalid term line: http://brand-prestige.com/signup/:1
# Skipping invalid term line: http://brew.sh/:1
# Skipping invalid term line: http://bugreport.apple.com:1
# Skipping invalid term line: http://bugreport.apple.com/:2
# Skipping invalid term line: http://buildnewgames.com/astar:1
# Skipping invalid term line: http://buildnewgames.com/astar/:1
# Skipping invalid term line: http://butlerccwebdev.net/support/testingserver/vhosts-setup-win.html:1
# Skipping invalid term line: http://bxslider.com/examples/image-slideshow-captions:1
# Skipping invalid term line: http://bxslider.com/lib/images/controls.png:1
# Skipping invalid term line: http://bxslider.com/lib/jquery.bxslider.css:1
# Skipping invalid term line: http://c2.com/ppr/checks.html#6:1
# Skipping invalid term line: http://caml.inria.fr/mantis/view.php?id=6017:1
# Skipping invalid term line: http://caniuse.com/#feat=css-animation:1
# Skipping invalid term line: http://caniuse.com/#feat=css-variables:1
# Skipping invalid term line: http://caniuse.com/#feat=input-number:1
# Skipping invalid term line: http://caniuse.com/#feat=viewport-units:1
# Skipping invalid term line: http://caniuse.com/#search=pushstate:1
# Skipping invalid term line: http://caniuse.com/#search=transform:1
# Skipping invalid term line: http://captcha.com/localizations/spanish-captcha.html#argentinian-spanish:1
# Skipping invalid term line: http://cbaileyns.github.io:1
# Skipping invalid term line: http://ccl.northwestern.edu/netlogo/docs/:1
# Skipping invalid term line: http://cdn.3960.org/_style/style.css:1
# Skipping invalid term line: http://cdn1.portalangop.co.ao/angola/pt_pt/files/highlight/2014/9/42/0,319a87a5-95c8-470d-acae-fd27d53e3ac1--r--NjQweDM0Mw==.jpg&quot:1
# Skipping invalid term line: http://centuryware.wordpress.com/2014/10/30/how-to-create-and-test-ios-apps-on-phonegap-build/:1
# Skipping invalid term line: http://cgcookiemarkets.com/blender/?s=retopology:1
# Skipping invalid term line: http://chandoo.org/wp/2009/11/10/excel-sumproduct-formula/:1
# Skipping invalid term line: http://chat.alexanderjank.de:1
# Skipping invalid term line: http://christianalfoni.github.io/javascript/2014/09/26/using-flux-with-angular.html:1
# Skipping invalid term line: http://christianspecht.de/2014/10/25/separate-pages-per-tag-category-with-jekyll-without-plugins/:1
# Skipping invalid term line: http://chrome.blogspot.co.uk/2014/01/everyone-can-now-track-down-noisy-tabs.html:1
# Skipping invalid term line: http://code.google.com/p/find-a-way/downloads/list:1
# Skipping invalid term line: http://code.tutsplus.com/tutorials/create-instagram-filters-with-php--net-24504:1
# Skipping invalid term line: http://code.tutsplus.com/tutorials/ios-sdk-crafting-custom-uitableview-cells--mobile-15702:1
# Skipping invalid term line: http://codeblog.jonskeet.uk/2011/01/02/reimplementing-linq-to-objects-part-23-take-skip-takewhile-skipwhile/:1
# Skipping invalid term line: http://codecorner.galanter.net/2014/09/02/reenable-showmodaldialog-in-chrome/:1
# Skipping invalid term line: http://codepad.org/cWZHjJwy:1
# Skipping invalid term line: http://codepad.org/mwtQKeas:1
# Skipping invalid term line: http://codepad.org/sGcyPimT:1
# Skipping invalid term line: http://codepad.viper-7.com/JDiU4h:1
# Skipping invalid term line: http://codepen.io/Jacob-McKay/pen/KCjpo:1
# Skipping invalid term line: http://codepen.io/SurajVerma/pen/Fskmu:1
# Skipping invalid term line: http://codepen.io/TryHardHusky/full/CclDE:1
# Skipping invalid term line: http://codepen.io/anon/pen/Drsxg?editors=101:1
# Skipping invalid term line: http://codepen.io/anon/pen/FzJDy:1
# Skipping invalid term line: http://codepen.io/anon/pen/LewqF:1
# Skipping invalid term line: http://codepen.io/anon/pen/eyDxI:1
# Skipping invalid term line: http://codepen.io/anon/pen/jduyE:1
# Skipping invalid term line: http://codepen.io/anon/pen/okKbl:1
# Skipping invalid term line: http://codepen.io/anon/pen/zkoCl:1
# Skipping invalid term line: http://codepen.io/anon/pen/zolLe:1
# Skipping invalid term line: http://codepen.io/farid/pen/CxAuy:1
# Skipping invalid term line: http://codepen.io/imm0rta1693/pen/zHtvK/:1
# Skipping invalid term line: http://codepen.io/jakeparis/pen/CGjni:1
# Skipping invalid term line: http://codepen.io/jeffreylauwers/pen/HfIFw:1
# Skipping invalid term line: http://codepen.io/macreart/pen/qtLEG:1
# Skipping invalid term line: http://codepen.io/pen/:1
# Skipping invalid term line: http://codepen.io/styler/pen/mAyIt:1
# Skipping invalid term line: http://codepen.io/xellos81/pen/cveCw:1
# Skipping invalid term line: http://codex.wordpress.org/Function_Reference/_e:1
# Skipping invalid term line: http://codex.wordpress.org/Function_Reference/get_terms:1
# Skipping invalid term line: http://codex.wordpress.org/Function_Reference/get_the_ID:1
# Skipping invalid term line: http://codex.wordpress.org/Function_Reference/get_the_term_list:1
# Skipping invalid term line: http://codex.wordpress.org/Function_Reference/is_single:1
# Skipping invalid term line: http://codex.wordpress.org/Function_Reference/wp_enqueue_script#Default_Scripts_Included_and_Registered_by_WordPress:1
# Skipping invalid term line: http://codex.wordpress.org/Function_Reference/wp_get_archives:1
# Skipping invalid term line: http://codex.wordpress.org/Function_Reference/wp_get_attachment_image:1
# Skipping invalid term line: http://codex.wordpress.org/Plugin_API/Filter_Reference/mce_external_plugins:1
# Skipping invalid term line: http://codex.wordpress.org/Widgets_API:1
# Skipping invalid term line: http://coheigea.blogspot.ie/2011/02/usernametoken-processing-changes-in.html:1
# Skipping invalid term line: http://coliru.stacked-crooked.com/a/273322175d57bd06:1
# Skipping invalid term line: http://coliru.stacked-crooked.com/a/6442251df000d0e7:1
# Skipping invalid term line: http://coliru.stacked-crooked.com/a/bf74d5f1c77fbc63:1
# Skipping invalid term line: http://commandwindows.com/batchfiles-branching.htm:1
# Skipping invalid term line: http://commons.apache.org/proper/commons-configuration/:1
# Skipping invalid term line: http://commons.apache.org/proper/commons-daemon/procrun.html:1
# Skipping invalid term line: http://commonservicelocator.codeplex.com/:1
# Skipping invalid term line: http://compass-style.org/reference/compass/typography/lists/horizontal_list/:1
# Skipping invalid term line: http://coolestguidesontheplanet.com/get-apache-mysql-php-phpmyadmin-working-osx-10-10-yosemite/:1
# Skipping invalid term line: http://coolestguidesontheplanet.com/how-to-change-the-mysql-root-password/:1
# Skipping invalid term line: http://coronalabs.com/blog/2013/02/11/using-the-ios-built-in-twitter-feature/:1
# Skipping invalid term line: http://cr.openjdk.java.net/~michaelm/7113349/7u4/2/jdk7u-osx/new/src/macosx/classes/com/apple/eawt/Application.java.html:1
# Skipping invalid term line: http://cr.yp.to/daemontools.html:1
# Skipping invalid term line: http://csgochat.info/aboutus.php:1
# Skipping invalid term line: http://cslibrary.stanford.edu/102/PointersAndMemory.pdf:1
# Skipping invalid term line: http://css-tricks.com/authoring-critical-fold-css/:1
# Skipping invalid term line: http://css-tricks.com/examples/GradientBorder/:1
# Skipping invalid term line: http://css-tricks.com/quick-css-trick-how-to-center-an-object-exactly-in-the-center/:1
# Skipping invalid term line: http://css-tricks.com/snippets/css/a-guide-to-flexbox/:1
# Skipping invalid term line: http://css-tricks.com/snippets/css/font-shorthand/:1
# Skipping invalid term line: http://css-tricks.com/snippets/css/using-font-face/:1
# Skipping invalid term line: http://cssdeck.com/labs/navigation-dropdown-with-flip-effect:1
# Skipping invalid term line: http://curl.haxx.se/libcurl/:1
# Skipping invalid term line: http://curl.haxx.se/libcurl/c/CURLOPT_POST.html:1
# Skipping invalid term line: http://curl.haxx.se/libcurl/c/fopen.html:1
# Skipping invalid term line: http://cznic.dl.sourceforge.net/project/pywin32/pywin32/Build%20219/pywin32-219.win32-py3.4.exe:1
# Skipping invalid term line: http://d.pr/i/U5bb/4n26fLZr:1
# Skipping invalid term line: http://dan.cx/2012/05/custom-strongly-typed-htmlhelpers-in-asp-net-mvc:1
# Skipping invalid term line: http://dave.cheney.net/2013/10/15/how-does-the-go-build-command-work:1
# Skipping invalid term line: http://davidstutz.github.io/bootstrap-multiselect/#post:1
# Skipping invalid term line: http://db.apache.org/derby/quick_start.html:1
# Skipping invalid term line: http://de.slideshare.net/DroidConTLV/android-crash-analysis-and-the-dalvik-garbage-collector-tools-and-tips:1
# Skipping invalid term line: http://de.wikipedia.org/wiki/Db4o:1
# Skipping invalid term line: http://demo.srchulo.com/jquery/jquery_facets/:1
# Skipping invalid term line: http://demos.telerik.com/aspnet-mvc/grid/hierarchy:1
# Skipping invalid term line: http://demosthenes.info/blog/586/CSS-Fluid-Image-Techniques-for-Responsive-Site-Design:1
# Skipping invalid term line: http://dennistel.nl/movies/:1
# Skipping invalid term line: http://designshack.net/tutorialexamples/verticalnav/index.html:1
# Skipping invalid term line: http://dev.baidu.com/wiki/map/in:1
# Skipping invalid term line: http://dev.day.com/docs/en/cq/current/administering/multi_site_manager.html:1
# Skipping invalid term line: http://dev.day.com/docs/v5_2/html-resources/cq5_guide_power_user/ch13s04.html:1
# Skipping invalid term line: http://dev.mysql.com/doc/connector-net/en/connector-net-programming-connecting-open.html:1
# Skipping invalid term line: http://dev.mysql.com/doc/refman/4.1/en/packet-too-large.html:1
# Skipping invalid term line: http://dev.mysql.com/doc/refman/5.0/en/join.html:1
# Skipping invalid term line: http://dev.mysql.com/doc/refman/5.0/en/privileges-provided.html#priv_select:1
# Skipping invalid term line: http://dev.mysql.com/doc/refman/5.0/en/replace.html:1
# Skipping invalid term line: http://dev.mysql.com/doc/refman/5.0/en/show-create-view.html:1
# Skipping invalid term line: http://dev.mysql.com/doc/refman/5.0/en/subqueries.html:1
# Skipping invalid term line: http://dev.mysql.com/doc/refman/5.5/en/insert-on-duplicate.html:1
# Skipping invalid term line: http://dev.mysql.com/doc/refman/5.6/en/enum.html:1
# Skipping invalid term line: http://dev.openlayers.org/releases/OpenLayers-2.13/doc/apidocs/files/OpenLayers/Format-js.html:1
# Skipping invalid term line: http://dev.w3.org/csswg/css-variables/:1
# Skipping invalid term line: http://developer.android.com/guide/components/fragments.html:1
# Skipping invalid term line: http://developer.android.com/guide/components/services.html#ExtendingIntentService:1
# Skipping invalid term line: http://developer.android.com/guide/practices/screens_support.html:1
# Skipping invalid term line: http://developer.android.com/guide/topics/appwidgets/:1
# Skipping invalid term line: http://developer.android.com/guide/topics/appwidgets/index.html#CreatingLayout:1
# Skipping invalid term line: http://developer.android.com/guide/topics/connectivity/wifip2p.html:1
# Skipping invalid term line: http://developer.android.com/guide/topics/data/backup.html:1
# Skipping invalid term line: http://developer.android.com/guide/topics/data/backup.html#SharedPreferences:1
# Skipping invalid term line: http://developer.android.com/guide/topics/data/data-storage.html#filesInternal:1
# Skipping invalid term line: http://developer.android.com/guide/topics/manifest/manifest-intro.html:1
# Skipping invalid term line: http://developer.android.com/guide/topics/manifest/manifest-intro.html#perms:1
# Skipping invalid term line: http://developer.android.com/guide/topics/media/camera.html#intents:1
# Skipping invalid term line: http://developer.android.com/guide/topics/media/camera.html#saving-media:1
# Skipping invalid term line: http://developer.android.com/guide/topics/resources/menu-resource.html:1
# Skipping invalid term line: http://developer.android.com/guide/topics/ui/layout/linear.html#Weight:1
# Skipping invalid term line: http://developer.android.com/guide/topics/ui/settings.html#Custom:1
# Skipping invalid term line: http://developer.android.com/index.html:1
# Skipping invalid term line: http://developer.android.com/reference/android/Manifest.permission.html#INTERNET:1
# Skipping invalid term line: http://developer.android.com/reference/android/app/Activity.html#getIntent():1
# Skipping invalid term line: http://developer.android.com/reference/android/app/Activity.html#onSaveInstanceState(android.os.Bundle):1
# Skipping invalid term line: http://developer.android.com/reference/android/app/FragmentManager.html:1
# Skipping invalid term line: http://developer.android.com/reference/android/app/FragmentTransaction.html:1
# Skipping invalid term line: http://developer.android.com/reference/android/app/PendingIntent.html:1
# Skipping invalid term line: http://developer.android.com/reference/android/app/Service.html:1
# Skipping invalid term line: http://developer.android.com/reference/android/content/ContentProvider.html:1
# Skipping invalid term line: http://developer.android.com/reference/android/content/ContentProvider.html#applyBatch(java.util.ArrayList%3Candroid.content.ContentProviderOperation%3E):1
# Skipping invalid term line: http://developer.android.com/reference/android/content/ContentProviderOperation.html:1
# Skipping invalid term line: http://developer.android.com/reference/android/content/Context.html#checkCallingPermission%28java.lang.String%29:1
# Skipping invalid term line: http://developer.android.com/reference/android/content/Context.html#getApplicationContext():1
# Skipping invalid term line: http://developer.android.com/reference/android/content/res/Resources.html#getDimensionPixelSize(int):1
# Skipping invalid term line: http://developer.android.com/reference/android/database/ContentObserver.html:1
# Skipping invalid term line: http://developer.android.com/reference/android/hardware/SensorListener.html:1
# Skipping invalid term line: http://developer.android.com/reference/android/media/AudioManager.html#startBluetoothSco():1
# Skipping invalid term line: http://developer.android.com/reference/android/os/AsyncTask.html:2
# Skipping invalid term line: http://developer.android.com/reference/android/os/SystemClock.html#elapsedRealtime%28%29:1
# Skipping invalid term line: http://developer.android.com/reference/android/preference/PreferenceManager.html#getDefaultSharedPreferences(android.content.Context):1
# Skipping invalid term line: http://developer.android.com/reference/android/util/AttributeSet.html:1
# Skipping invalid term line: http://developer.android.com/reference/android/view/Gravity.html:1
# Skipping invalid term line: http://developer.android.com/reference/android/view/View.html#getId%28%29:1
# Skipping invalid term line: http://developer.android.com/reference/android/view/View.html#setEnabled(boolean):1
# Skipping invalid term line: http://developer.android.com/reference/android/widget/Button.html:1
# Skipping invalid term line: http://developer.android.com/reference/android/widget/ImageButton.html:1
# Skipping invalid term line: http://developer.android.com/reference/android/widget/PopupWindow.OnDismissListener.html:1
# Skipping invalid term line: http://developer.android.com/reference/android/widget/ScrollView.html:1
# Skipping invalid term line: http://developer.android.com/reference/android/widget/TextView.html:1
# Skipping invalid term line: http://developer.android.com/reference/com/google/android/gms/ads/doubleclick/PublisherAdRequest.Builder.html#addNetworkExtras(com.google.android.gms.ads.mediation.NetworkExtras):1
# Skipping invalid term line: http://developer.android.com/reference/com/google/android/gms/maps/GoogleMap.OnCameraChangeListener.html:1
# Skipping invalid term line: http://developer.android.com/reference/com/google/android/gms/maps/MapView.html#onSaveInstanceState(android.os.Bundle):1
# Skipping invalid term line: http://developer.android.com/reference/java/net/URL.html:1
# Skipping invalid term line: http://developer.android.com/reference/java/net/URLEncoder.html:1
# Skipping invalid term line: http://developer.android.com/reference/java/util/Locale.html:1
# Skipping invalid term line: http://developer.android.com/shareables/devbytes/ListViewDraggingAnimation.zip:1
# Skipping invalid term line: http://developer.android.com/tools/publishing/app-signing.html:1
# Skipping invalid term line: http://developer.android.com/tools/sdk/ndk/index.html:1
# Skipping invalid term line: http://developer.android.com/tools/support-library/setup.html#add-library:1
# Skipping invalid term line: http://developer.android.com/training/animation/screen-slide.html:1
# Skipping invalid term line: http://developer.android.com/training/custom-views/create-view.html:1
# Skipping invalid term line: http://developer.android.com/training/implementing-navigation/ancestral.html:1
# Skipping invalid term line: http://developer.android.com/training/implementing-navigation/nav-drawer.html:1
# Skipping invalid term line: http://developer.android.com/training/implementing-navigation/temporal.html#back-fragments:1
# Skipping invalid term line: http://developer.android.com/training/improving-layouts/smooth-scrolling.html:1
# Skipping invalid term line: http://developer.android.com/training/multiscreen/screensizes.html:1
# Skipping invalid term line: http://developer.android.com/training/volley/requestqueue.html:1
# Skipping invalid term line: http://developer.apple.com/iphone/library/samplecode/KeyboardAccessory/Listings/Classes_ViewController_m.html:1
# Skipping invalid term line: http://developer.factual.com/api-docs/#Multi:1
# Skipping invalid term line: http://developer.marklogic.com/pipermail/general/2009-December/004200.html:1
# Skipping invalid term line: http://developer.teradata.com/doc/connectivity/jdbc/reference/current/samp/T20205JD.java.txt:1
# Skipping invalid term line: http://developer.xamarin.com/guides/android/user_interface/creating_a_splash_screen/:1
# Skipping invalid term line: http://developer.xamarin.com/recipes/ios/standard_controls/actionsheet/display_an_actionsheet/:1
# Skipping invalid term line: http://developers.marketo.com/documentation/rest/custom-service/:1
# Skipping invalid term line: http://devnet.jetbrains.com/thread/436515:1
# Skipping invalid term line: http://digitalstore.pk/contact.html:1
# Skipping invalid term line: http://distinctplace.com/infrastructure/2013/10/14/internal-redirect-to-another-domain-with-proxy_pass-and-nginx/:1
# Skipping invalid term line: http://dl.acm.org/citation.cfm?id=2628136.2628139:1
# Skipping invalid term line: http://doc-snapshot.qt-project.org/qt5-5.4/qgraphicsview.html#DragMode-enum:1
# Skipping invalid term line: http://doc.akka.io/docs/akka/snapshot/scala/actors.html#stash:1
# Skipping invalid term line: http://doc.rust-lang.org/std/f64/primitive.f64.html:1
# Skipping invalid term line: http://doc.scrapy.org/en/latest/topics/link-extractors.html:1
# Skipping invalid term line: http://docs.amcharts.com/3/javascriptcharts/AmBalloon:1
# Skipping invalid term line: http://docs.amcharts.com/3/javascriptcharts/AmGraph#bullet:1
# Skipping invalid term line: http://docs.amcharts.com/3/javascriptcharts/ValueAxis:1
# Skipping invalid term line: http://docs.ansible.com/get_url_module.html:1
# Skipping invalid term line: http://docs.ansible.com/uri_module.html:1
# Skipping invalid term line: http://docs.appcelerator.com/titanium/latest/#!/api/Titanium.UI.View-method-toImage:1
# Skipping invalid term line: http://docs.aws.amazon.com/AWSRubySDK/latest/frames.html:1
# Skipping invalid term line: http://docs.aws.amazon.com/amazondynamodb/latest/developerguide/Tools.DynamoDBLocal.html:1
# Skipping invalid term line: http://docs.aws.amazon.com/elasticbeanstalk/latest/dg/create_deploy_nodejs_express.html:1
# Skipping invalid term line: http://docs.ckan.org/en/943-writing-extensions-tutorial/paster.html:1
# Skipping invalid term line: http://docs.couchbase.com/developer/node-2.0/documents.html:1
# Skipping invalid term line: http://docs.dhtmlx.com/gantt/api__gantt_getstate.html:1
# Skipping invalid term line: http://docs.dhtmlx.com/gantt/api__gantt_scale_offset_minimal_config.html:1
# Skipping invalid term line: http://docs.gstreamer.com/display/GstSDK/Basic+tutorial+5%3A+GUI+toolkit+integration:1
# Skipping invalid term line: http://docs.guava-libraries.googlecode.com/git/javadoc/com/google/common/base/Equivalence.html:1
# Skipping invalid term line: http://docs.guava-libraries.googlecode.com/git/javadoc/com/google/common/collect/ImmutableSet.html:1
# Skipping invalid term line: http://docs.hortonworks.com/HDPDocuments/Ambari-1.6.1.0/bk_using_Ambari_book/content/ambari-chap1-6.html:1
# Skipping invalid term line: http://docs.hortonworks.com/HDPDocuments/Ambari-1.6.1.0/bk_using_Ambari_book/content/ambari-chap1.html:1
# Skipping invalid term line: http://docs.jboss.org/infinispan/6.0/apidocs/org/infinispan/AdvancedCache.html#withFlags%28org.infinispan.context.Flag...%29:1
# Skipping invalid term line: http://docs.jboss.org/infinispan/6.0/apidocs/org/infinispan/context/Flag.html#SKIP_INDEXING:1
# Skipping invalid term line: http://docs.jboss.org/seam/2.2.2.Final/api/org/jboss/seam/framework/EntityHome.html:1
# Skipping invalid term line: http://docs.joomla.org/How_to_check_if_mod_rewrite_is_enabled_on_your_server:1
# Skipping invalid term line: http://docs.makotemplates.org/en/latest/usage.html:1
# Skipping invalid term line: http://docs.mongodb.org/manual/reference/gridfs/#gridfs-reference:1
# Skipping invalid term line: http://docs.mongodb.org/manual/reference/method/cursor.sort/:1
# Skipping invalid term line: http://docs.mongodb.org/manual/reference/operator/projection/positional/#proj.:1
# Skipping invalid term line: http://docs.mongodb.org/manual/reference/operator/projection/positional/#proj._S_:1
# Skipping invalid term line: http://docs.mongodb.org/manual/reference/operator/query/geoIntersects/#op._S_geoIntersects:1
# Skipping invalid term line: http://docs.mongodb.org/manual/reference/operator/query/in/:1
# Skipping invalid term line: http://docs.nuget.org/docs/creating-packages/configuration-file-and-source-code-transformations:1
# Skipping invalid term line: http://docs.opencv.org/:1
# Skipping invalid term line: http://docs.opencv.org/modules/imgproc/doc/structural_analysis_and_shape_descriptors.html:1
# Skipping invalid term line: http://docs.oracle.com/cd/B10500_01/server.920/a96533/hintsref.htm:1
# Skipping invalid term line: http://docs.oracle.com/cd/B28359_01/appdev.111/b28425/aggr_functions.htm:1
# Skipping invalid term line: http://docs.oracle.com/cd/B28359_01/olap.111/b28126/dml_functions_2049.htm:1
# Skipping invalid term line: http://docs.oracle.com/cd/B28359_01/server.111/b28274/hintsref.htm#PFGRF501:1
# Skipping invalid term line: http://docs.oracle.com/cd/B28359_01/server.111/b28310/views002.htm#ADMIN11792:1
# Skipping invalid term line: http://docs.oracle.com/cd/B28359_01/server.111/b28313/basicmv.htm:1
# Skipping invalid term line: http://docs.oracle.com/cd/E11882_01/appdev.112/e11822/adobjcol.htm#ADOBJ7284:1
# Skipping invalid term line: http://docs.oracle.com/cd/E11882_01/server.112/e10729/ch4datetime.htm#NLSPG004:1
# Skipping invalid term line: http://docs.oracle.com/cd/E19957-01/806-3568/ncg_goldberg.html:1
# Skipping invalid term line: http://docs.oracle.com/database/121/SQLRF/statements_6017.htm#SQLRF01314:1
# Skipping invalid term line: http://docs.oracle.com/javaee/6/api/javax/servlet/ServletResponse.html#getOutputStream():1
# Skipping invalid term line: http://docs.oracle.com/javaee/6/api/javax/servlet/ServletResponse.html#setContentType(java.lang.String):1
# Skipping invalid term line: http://docs.oracle.com/javafx/2/api/javafx/embed/swing/JFXPanel.html:1
# Skipping invalid term line: http://docs.oracle.com/javafx/2/api/javafx/scene/media/Media.html#Media(java.lang.String):1
# Skipping invalid term line: http://docs.oracle.com/javase/6/docs/technotes/tools/share/xjc.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/7/docs/api/java/io/File.html:2
# Skipping invalid term line: http://docs.oracle.com/javase/7/docs/api/java/io/File.html#File(java.lang.String):1
# Skipping invalid term line: http://docs.oracle.com/javase/7/docs/api/java/io/File.html#toURI():1
# Skipping invalid term line: http://docs.oracle.com/javase/7/docs/api/java/io/PrintWriter.html#printf%28java.lang.String,%20java.lang.Object...%29:1
# Skipping invalid term line: http://docs.oracle.com/javase/7/docs/api/java/lang/ProcessBuilder.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/7/docs/api/java/lang/String.html#split(java.lang.String):1
# Skipping invalid term line: http://docs.oracle.com/javase/7/docs/api/java/math/BigDecimal.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/7/docs/api/java/net/URLEncoder.html#encode(java.lang.String,%20java.lang.String):1
# Skipping invalid term line: http://docs.oracle.com/javase/7/docs/api/java/nio/charset/CharsetEncoder.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/7/docs/api/java/security/KeyFactory.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/7/docs/api/java/sql/ResultSetMetaData.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/7/docs/api/java/sql/SQLException.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/7/docs/api/java/util/Calendar.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/7/docs/api/java/util/Calendar.html#MONTH:1
# Skipping invalid term line: http://docs.oracle.com/javase/7/docs/api/java/util/Collections.html#shuffle(java.util.List):1
# Skipping invalid term line: http://docs.oracle.com/javase/7/docs/api/java/util/Deque.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/7/docs/api/java/util/Scanner.html#next%28%29:1
# Skipping invalid term line: http://docs.oracle.com/javase/7/docs/api/java/util/regex/Matcher.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/7/docs/api/java/util/regex/Pattern.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/7/docs/api/javax/swing/JApplet.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/7/docs/api/javax/xml/bind/DatatypeConverter.html#parseBase64Binary(java.lang.String):1
# Skipping invalid term line: http://docs.oracle.com/javase/7/docs/technotes/guides/language/underscores-literals.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/8/docs/api/java/io/InputStreamReader.html#InputStreamReader-java.io.InputStream-:1
# Skipping invalid term line: http://docs.oracle.com/javase/8/docs/api/java/text/SimpleDateFormat.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/8/docs/api/java/util/Formatter.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/8/docs/api/java/util/Set.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/8/docs/api/java/util/stream/Stream.html#distinct--:1
# Skipping invalid term line: http://docs.oracle.com/javase/8/docs/api/java/util/stream/package-summary.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/8/docs/technotes/guides/visualvm/:1
# Skipping invalid term line: http://docs.oracle.com/javase/8/javafx/api/javafx/animation/Timeline.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/8/javafx/api/javafx/application/Platform.html#runLater-java.lang.Runnable-:1
# Skipping invalid term line: http://docs.oracle.com/javase/8/javafx/api/javafx/concurrent/Task.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/8/javafx/api/javafx/scene/Node.html#snapshot-javafx.scene.SnapshotParameters-javafx.scene.image.WritableImage-:1
# Skipping invalid term line: http://docs.oracle.com/javase/specs/#7.5:1
# Skipping invalid term line: http://docs.oracle.com/javase/specs/jls/se7/html/jls-8.html#jls-8.4.8:1
# Skipping invalid term line: http://docs.oracle.com/javase/specs/jls/se7/html/jls-9.html#jls-9.4.1:1
# Skipping invalid term line: http://docs.oracle.com/javase/specs/jls/se8/html/jls-15.html#jls-15.20.1:1
# Skipping invalid term line: http://docs.oracle.com/javase/specs/jls/se8/html/jls-15.html#jls-15.9.2:1
# Skipping invalid term line: http://docs.oracle.com/javase/specs/jls/se8/html/jls-8.html#jls-8.8:1
# Skipping invalid term line: http://docs.oracle.com/javase/tutorial/deployment/applet/index.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/tutorial/java/data/numberformat.html:2
# Skipping invalid term line: http://docs.oracle.com/javase/tutorial/java/generics/rawTypes.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/tutorial/java/nutsandbolts/for.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/tutorial/java/nutsandbolts/op2.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/tutorial/jaxb/intro/:1
# Skipping invalid term line: http://docs.oracle.com/javase/tutorial/jdbc/:1
# Skipping invalid term line: http://docs.oracle.com/javase/tutorial/jdbc/basics/sqlexception.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/tutorial/reflect/:1
# Skipping invalid term line: http://docs.oracle.com/javase/tutorial/uiswing/components/buttongroup.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/tutorial/uiswing/components/frame.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/tutorial/uiswing/components/layeredpane.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/tutorial/uiswing/components/table.html#editrender:1
# Skipping invalid term line: http://docs.oracle.com/javase/tutorial/uiswing/concurrency/:2
# Skipping invalid term line: http://docs.oracle.com/javase/tutorial/uiswing/concurrency/initial.html:1
# Skipping invalid term line: http://docs.oracle.com/javase/tutorial/uiswing/misc/timer.html:1
# Skipping invalid term line: http://docs.php.net/class.mysqli-sql-exception:1
# Skipping invalid term line: http://docs.php.net/get_browser:1
# Skipping invalid term line: http://docs.php.net/pdo:1
# Skipping invalid term line: http://docs.pylonsproject.org/projects/pyramid/en/latest/tutorials/modwsgi/index.html:1
# Skipping invalid term line: http://docs.scipy.org/doc/numpy/reference/routines.functional.html:1
# Skipping invalid term line: http://docs.seleniumhq.org/docs/02_selenium_ide.jsp#selenium-commands-selenese:1
# Skipping invalid term line: http://docs.spring.io/spring-batch-admin/:1
# Skipping invalid term line: http://docs.spring.io/spring-boot/docs/current-SNAPSHOT/reference/htmlsingle/#common-application-properties:1
# Skipping invalid term line: http://docs.spring.io/spring-framework/docs/2.5.x/api/org/springframework/util/AntPathMatcher.html:1
# Skipping invalid term line: http://docs.spring.io/spring-framework/docs/current/spring-framework-reference/html/expressions.html#expressions-beandef-xml-based:1
# Skipping invalid term line: http://docs.spring.io/spring-integration/reference/html/sftp.html#sftp-jsch-logging:1
# Skipping invalid term line: http://docs.spring.io/spring-security/site/docs/3.2.x/apidocs/org/springframework/security/core/GrantedAuthority.html:1
# Skipping invalid term line: http://docs.spring.io/spring/docs/current/javadoc-api/org/springframework/web/bind/annotation/RequestParam.html:1
# Skipping invalid term line: http://docs.sqlalchemy.org/en/rel_0_9/orm/relationships.html:1
# Skipping invalid term line: http://docs.strongloop.com/display/LB/Remote+hooks:1
# Skipping invalid term line: http://docs.telerik.com/kendo-ui/api/javascript/data/datasource#configuration-pageSize:1
# Skipping invalid term line: http://docstore.mik.ua/orelly/linux/sql/ch13_01.htm:1
# Skipping invalid term line: http://doctrine-orm.readthedocs.org/en/latest/reference/batch-processing.html#iterating-large-results-for-data-processing:1
# Skipping invalid term line: http://docwiki.embarcadero.com/Libraries/XE4/en/Data.Win.ADODB.TADOConnection.Errors:1
# Skipping invalid term line: http://domain.com/api/locations/codeforlocation:1
# Skipping invalid term line: http://domain.com/api/locations/import:1
# Skipping invalid term line: http://domain.com/login/file.txt:1
# Skipping invalid term line: http://domain.com/user/file.txt:1
# Skipping invalid term line: http://dygraphs.com/tests/value-axis-formatters.html:1
# Skipping invalid term line: http://dyn.com/dns/:1
# Skipping invalid term line: http://dyn.com/managed-dns/:1
# Skipping invalid term line: http://ecma-international.org/ecma-262/5.1/#sec-11.9.3:1
# Skipping invalid term line: http://emailtheweb.com:1
# Skipping invalid term line: http://embed.plnkr.co/I2vmyTxK2kN3slqCQxFV/preview:1
# Skipping invalid term line: http://embed.plnkr.co/rjQ1U3rsFDASvZpHElCW/:1
# Skipping invalid term line: http://emberjs.com/api/classes/Ember.Observable.html#method_removeObserver:1
# Skipping invalid term line: http://emberjs.jsbin.com/pijaka/1/:1
# Skipping invalid term line: http://en.cppreference.com/w/cpp/io/basic_istream/read:1
# Skipping invalid term line: http://en.cppreference.com/w/cpp/io/manip/setprecision:1
# Skipping invalid term line: http://en.cppreference.com/w/cpp/language/delete:1
# Skipping invalid term line: http://en.cppreference.com/w/cpp/language/expressions:1
# Skipping invalid term line: http://en.cppreference.com/w/cpp/types/climits:1
# Skipping invalid term line: http://en.wikibooks.org/wiki/JPEG_-_Idea_and_Practice/The_header_part:1
# Skipping invalid term line: http://en.wikibooks.org/wiki/Learning_Clojure/Reader_Macros:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/%C3%81:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/A*_search_algorithm:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/ALGOL_68:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/ASCII:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Ackermann_function:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Apache_Ant:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Asia/Krasnoyarsk:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Blend_modes:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Boolean_algebra:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/CORDIC:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Cartesian_product:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Character_encoding:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Circular_buffer:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Compression_artifact:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Continuous_delivery:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Coordinated_Universal_Time:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Corner_case:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Decorator_pattern:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Delegation_%28programming%29:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Dependency_injection:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Deterministic_finite_automaton:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Distance_from_a_point_to_a_line:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Dodecahedron:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Eight_queens_puzzle:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Euclidean_algorithm:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Exchangeable_image_file_format:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Executable_and_Linkable_Format:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Fork_%28system_call%29:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Function_object#In_C_and_C.2B.2B:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Fuser_(Unix):1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Geographical_distance#Singularities_and_discontinuity_of_latitude.2Flongitude:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Geometric_series#Sum:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Graphical_user_interface:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/HTTP_cookie#HttpOnly_cookie:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Heaviside_step_function:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/JPEG#JPEG_files:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Java_Servlet:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Join_%28SQL%29#Outer_join:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Las_Vegas_algorithm:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Law_of_Demeter:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Levenshtein_distance:2
# Skipping invalid term line: http://en.wikipedia.org/wiki/Line%E2%80%93line_intersection:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Line_(geometry)#Cartesian_plane:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/List_of_tz_database_time_zones:2
# Skipping invalid term line: http://en.wikipedia.org/wiki/List_of_widget_toolkits:1
# Skipping invalid term line: http://en.wikipedia.org/wiki/Marginal_distribution:1
# ...
# Skipping invalid term line: https://stackoverflow.com/users/3152130/taw:1
# Skipping invalid term line: https://stackoverflow.com/users/3474/erickson:1
# Skipping invalid term line: https://stackoverflow.com/users/604364/gabor-csardi:1
# Skipping invalid term line: https://stackoverflow.com/users/687981/cmckeegan:1
# Skipping invalid term line: https://stats.stackexchange.com/questions/97708/how-can-i-modify-default-parameters-of-a-gbm-step-plot:1
# Skipping invalid term line: https://store.continuum.io/cshop/anaconda/:1
# Skipping invalid term line: https://supermarket.getchef.com/cookbooks/chocolatey:1
# Skipping invalid term line: https://superuser.com/a/743531:1
# Skipping invalid term line: https://superuser.com/questions/211236/automatic-log-in-in-linux:1
# Skipping invalid term line: https://superuser.com/questions/366651/redirecting-input-from-file-to-command-line-program/366671#comment1096050_366671:1
# Skipping invalid term line: https://superuser.com/questions/818797/outlook-2013-calendar-contacts-how-to-mark-all-as-read:1
# Skipping invalid term line: https://support.microsoft.com/kb/2670838/de-de?ppud=4&wa=wsignin1.0:1
# Skipping invalid term line: https://support.pivotal.io/hc/en-us/articles/202635496-How-to-access-HDFS-data-via-GPDB-external-table-with-gphdfs-protocol:1
# Skipping invalid term line: https://svn.wso2.org/repos/wso2/carbon/platform/trunk/:1
# Skipping invalid term line: https://thinkster.io/egghead/routeparams-api/:1
# Skipping invalid term line: https://trac.ffmpeg.org/wiki/Create%20a%20video%20slideshow%20from%20images:1
# Skipping invalid term line: https://triagens.github.io/ashikawa-core/:1
# Skipping invalid term line: https://twistedmatrix.com/documents/current/api/twisted.pair.html:1
# Skipping invalid term line: https://typekit.com/:1
# Skipping invalid term line: https://umbc.t2hosted.com/cit/index.aspx:1
# Skipping invalid term line: https://unix.stackexchange.com/questions/165059/how-to-set-lang-in-locale-despite-its-in-etc-default-locale-in-ubuntu-for-uni:1
# Skipping invalid term line: https://unix.stackexchange.com/questions/16564/why-are-the-first-1024-ports-restricted-to-the-root-user-only:1
# Skipping invalid term line: https://vaadin.com/book/-/page/components.table.html#components.table.columngenerator:1
# Skipping invalid term line: https://vagrantcloud.com/ubuntu/boxes/trusty64:1
# Skipping invalid term line: https://vimeo.com/36385012:1
# Skipping invalid term line: https://visualstudio.uservoice.com/forums/121579-visual-studio/suggestions/6634431-give-filesystemwatcher-the-power-to-detect-file-m:1
# Skipping invalid term line: https://visualstudiogallery.msdn.microsoft.com/6ab922d0-21c0-4f06-ab5f-4ecd1fe7175d/view/Discussions:1
# Skipping invalid term line: https://wapiex.codeplex.com/:1
# Skipping invalid term line: https://web.archive.org/web/20141105042930/http://www.regentsprep.org/regents/math/algtrig/atp2/geoseq.htm:1
# Skipping invalid term line: https://web.archive.org/web/20141204104430/http://www.onehippo.org:80/library/concepts/request-handling/mount-matching.html:1
# Skipping invalid term line: https://webmatrix.uservoice.com/forums/128313-webmatrix-suggestions:1
# Skipping invalid term line: https://wiki.alfresco.com/wiki/Benchmark_Framework_2.0:_Developing_Tests:1
# Skipping invalid term line: https://wiki.apache.org/solr/Core%20Discovery%20%284.4%20and%20beyond%29:1
# Skipping invalid term line: https://wiki.jenkins-ci.org/display/JENKINS/EnvInject+Plugin:1
# Skipping invalid term line: https://wiki.jenkins-ci.org/display/JENKINS/EnvInject+Plugin#EnvInjectPlugin-Injectvariablesasabuildstep:1
# Skipping invalid term line: https://wiki.jenkins-ci.org/display/JENKINS/Installing+Jenkins+as+a+Windows+service:1
# Skipping invalid term line: https://wiki.jenkins-ci.org/display/JENKINS/Plugin+tutorial:1
# Skipping invalid term line: https://wiki.ubuntu.com/Touch/ContainerArchitecture:1
# Skipping invalid term line: https://wikidocs.adobe.com/wiki/display/coldfusionen/ArrayReduce:1
# Skipping invalid term line: https://wordpress.org/plugins/autoptimize/:1
# Skipping invalid term line: https://wordpress.org/plugins/multiple-post-thumbnails/:1
# Skipping invalid term line: https://wordpress.org/plugins/rewrite-rules-inspector/:1
# Skipping invalid term line: https://wordpress.org/plugins/svg-support/:1
# Skipping invalid term line: https://wordpress.stackexchange.com/questions/167156/url-rewrite-and-navigation-structure-for-wordpress-custom-post-type:1
# Skipping invalid term line: https://wpfwf.codeplex.com/:1
# Skipping invalid term line: https://www.airbnb.com/:1
# Skipping invalid term line: https://www.arangodb.com/:1
# Skipping invalid term line: https://www.assetstore.unity3d.com/en/#!/content/22867:1
# Skipping invalid term line: https://www.atlassian.com/git/tutorials/making-a-pull-request/how-it-works:1
# Skipping invalid term line: https://www.atlassian.com/git/workflows#!workflow-gitflow:1
# Skipping invalid term line: https://www.browserleaks.com/modernizr:1
# Skipping invalid term line: https://www.casinthecloud.com:1
# Skipping invalid term line: https://www.cis.upenn.edu/~matuszek/cit594-2012/Pages/backtracking.html:1
# Skipping invalid term line: https://www.damircalusic.se/portfolio/:1
# Skipping invalid term line: https://www.daniweb.com/web-development/databases/mysql/threads/178612/insert-data-into-two-tables-using-php-and-mysql:1
# Skipping invalid term line: https://www.docker.com/docker-toolbox:1
# Skipping invalid term line: https://www.dropbox.com/s/3rw3guxge76tbyl/ToolBarTest.zip?dl=0:1
# Skipping invalid term line: https://www.dropbox.com/s/8u6d3bfn854iso2/Screenshot%202014-10-31%2012.40.18.png?dl=0:1
# Skipping invalid term line: https://www.dropbox.com/s/ccnuqmsxdtb75xl/com.android.vending.apk:1
# Skipping invalid term line: https://www.dropbox.com/s/g7idbhuqn57n70j/BCM20793S-datasheet.pdf?dl=0:1
# Skipping invalid term line: https://www.dropbox.com/s/omqj5121ev43mxc/Test.py?dl=0:1
# Skipping invalid term line: https://www.dropbox.com/s/p0ex29s6r6v65nu/NSBConfiguration.png?dl=0:1
# Skipping invalid term line: https://www.dropbox.com/s/ploicaku01mmyj1/WpfApplication4.zip?dl=0:1
# Skipping invalid term line: https://www.dropbox.com/sh/acrtzuaq1edp7f5/AADVxq00DNgbmz-66uA42E5sa?dl=0:1
# Skipping invalid term line: https://www.facebook.com/settings?tab=applications:1
# Skipping invalid term line: https://www.firebase.com/docs/beta/queries/rest.html:1
# Skipping invalid term line: https://www.firebase.com/docs/web/libraries/angular/guide.html#section-basics:1
# Skipping invalid term line: https://www.gmail.com:1
# Skipping invalid term line: https://www.gnu.org/software/bash/manual/bashref.html#Word-Splitting:1
# Skipping invalid term line: https://www.gnu.org/software/gperf/manual/gperf.html:1
# Skipping invalid term line: https://www.golemtechnologies.com/articles/data-security-and-json:1
# Skipping invalid term line: https://www.google.com.au/search?q=sort%20verb%20cobol&ie=utf-8&oe=utf-8&aq=t&rls=org.mozilla:en-US:official&client=firefox-a&channel=nts&gfe_rd=cr&ei=6KFRVK_-BceN8QeMoYCwAg:1
# Skipping invalid term line: https://www.google.com/#q=what+is+my+ip:1
# Skipping invalid term line: https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=1&cad=rja&uact=8&ved=0CCIQFjAA&url=https%3A%2F%2Fdeveloper.apple.com%2Fdesign%2Fadaptivity%2F&ei=ExNUVI_RHMuiNoewgJgK&usg=AFQjCNGFXDxgxLzkjkgWItjYPTZMLmunzQ&sig2=h49oA2Wu9CEaSEZg0XMyAA&bvm=bv.78677474,d.eXY:1
# Skipping invalid term line: https://www.google.com/webmasters/:1
# Skipping invalid term line: https://www.google.fr/url?sa=t&rct=j&q=&esrc=s&source=web&cd=1&ved=0CCAQFjAA&url=http%3A%2F%2Fdeveloper.download.nvidia.com%2Fcompute%2Fcuda%2FCUDA_Occupancy_calculator.xls&ei=4VpSVOHOM4qVavCOgrgF&usg=AFQjCNG_VhxwvgVBBUZnnincdbTyvYLrKQ&sig2=hO7PJCM42Bo22ZNkF6babA:1
# Skipping invalid term line: https://www.googleapis.com/oauth2/v1/cert:1
# Skipping invalid term line: https://www.hackerrank.com/challenges/equations:1
# Skipping invalid term line: https://www.haskell.org/ghc/docs/latest/html/users_guide/type-families.html#assoc-decl:1
# Skipping invalid term line: https://www.haskell.org/haskellwiki/Bottom:1
# Skipping invalid term line: https://www.ibm.com/developerworks/community/blogs/kevgrig/entry/approximate_overhead_of_system_calls9?lang=en:1
# Skipping invalid term line: https://www.ibm.com/developerworks/community/blogs/victorsh/entry/march_11_2014_8_58_pm?lang=en:1
# Skipping invalid term line: https://www.ibm.com/developerworks/community/blogs/worklight/entry/action_required_cordova_android_security_update?lang=en:1
# Skipping invalid term line: https://www.ibm.com/support/docview.wss?uid=swg21405302:1
# Skipping invalid term line: https://www.igniterealtime.org/projects/openfire/plugins/mucservice/readme.html:1
# Skipping invalid term line: https://www.informit.com/guides/content.aspx?g=dotnet&seqNum=693:1
# Skipping invalid term line: https://www.jetbrains.com/idea/download/:1
# Skipping invalid term line: https://www.jstatsoft.org/article/view/v045i03:1
# Skipping invalid term line: https://www.khronos.org/opengles/sdk/docs/man3/:1
# Skipping invalid term line: https://www.khronos.org/registry/cl/api/1.1/cl.h:1
# Skipping invalid term line: https://www.kimonolabs.com/api/8dfvxr3a?apikey=5747a54d5ca762895b474cc224943240:1
# Skipping invalid term line: https://www.linkedin.com/pulse/vstoinstallerexeconfig-causes-many-office-add-ons-fail-guido-leenders:1
# Skipping invalid term line: https://www.meteor.com/projects:1
# Skipping invalid term line: https://www.mikeash.com/pyblog/friday-qa-2010-12-17-custom-object-allocators-in-objective-c.html:1
# Skipping invalid term line: https://www.npmjs.org/package/mkdirp:1
# Skipping invalid term line: https://www.npmjs.org/package/prompt:1
# Skipping invalid term line: https://www.npmjs.org/package/read:1
# Skipping invalid term line: https://www.nuget.org/packages/HtmlAgilityPack-PCL/:1
# Skipping invalid term line: https://www.nuget.org/packages/Microsoft.AspNet.WebApi.Client/:1
# Skipping invalid term line: https://www.nuget.org/packages/Rotativa/:1
# Skipping invalid term line: https://www.nuget.org/packages/TrackerEnabledDbContext:3
# Skipping invalid term line: https://www.odesk.com/:1
# Skipping invalid term line: https://www.onenote.com/api/beta/resources/:1
# Skipping invalid term line: https://www.open-std.org/jtc1/sc22/wg21/docs/papers/2004/n1607.pdf:1
# Skipping invalid term line: https://www.open-std.org/jtc1/sc22/wg21/docs/papers/2023/p2958r0.html:1
# Skipping invalid term line: https://www.opengl.org/sdk/docs/man2/xhtml/glColorMaterial.xml:1
# Skipping invalid term line: https://www.openssl.org/docs/ssl/SSL_get_current_cipher.html:1
# Skipping invalid term line: https://www.osadl.org/Realtime-Preempt-Kernel.kernel-rt.0.html#testingandusing:1
# Skipping invalid term line: https://www.owasp.org/index.php/Category:OWASP_Encoding_Project:1
# Skipping invalid term line: https://www.packtpub.com/virtualization-and-cloud/citrix-xenapp:1
# Skipping invalid term line: https://www.parse.com/docs/rest#queries:1
# Skipping invalid term line: https://www.payu.in/index:1
# Skipping invalid term line: https://www.php.net/array_Slice:1
# Skipping invalid term line: https://www.php.net/manual/en/book.pdo.php:2
# Skipping invalid term line: https://www.recognizeapp.com/:1
# Skipping invalid term line: https://www.rfc-editor.org/rfc/rfc5988:1
# Skipping invalid term line: https://www.rfc-editor.org/rfc/rfc7159:1
# Skipping invalid term line: https://www.ruby-lang.org/en/news/2013/12/17/maintenance-of-1-8-7-and-1-9-2/:1
# Skipping invalid term line: https://www.sandbox.paypal.com:1
# Skipping invalid term line: https://www.stgraber.org/2013/12/23/lxc-1-0-some-more-advanced-container-usage/:1
# Skipping invalid term line: https://www.twilio.com/docs/api/twiml:1
# Skipping invalid term line: https://www.us-cert.gov/ncas/alerts/TA14-290A:1
# Skipping invalid term line: https://www.v33r.tk:1
# Skipping invalid term line: https://www.webcubes.eu/spacetiles/:1
# Skipping invalid term line: https://www.wireshark.org/:1
# Skipping invalid term line: https://www.youtube.com/embed/FCuq3IedO9k?allowScriptAccess=always&controls=0&disablekb=1&enablejsapi=1&playsinline=1&iv_load_policy=3&modestbranding=1&start=151&rel=0&vq=large&showinfo=0&wmode=opaque&origin=http%3A%2F%2Fwww.meograph.com:1
# Skipping invalid term line: https://www.youtube.com/watch?v=P-mMvhfJhu8:1
# Skipping invalid term line: https://www.youtube.com/watch?v=T-enEltDNko:1
# Skipping invalid term line: https://www.youtube.com/watch?v=W45Ysb9b6oE:1
# Skipping invalid term line: https://www.youtube.com/watch?v=Yr1YnOVG-4g&feature=PlayList&p=9D558D49CA734A02&index=6:1
# Skipping invalid term line: https://www.youtube.com/watch?v=ZIIuPo4F6tQ:1
# Skipping invalid term line: https://www.youtube.com/watch?v=_BZIvjMgH-Q:1
# Skipping invalid term line: https://www.youtube.com/watch?v=aHm36-na4-4:1
# Skipping invalid term line: https://www.youtube.com/watch?v=gNmWybAyBHI:1
# Skipping invalid term line: https://www.youtube.com/watch?v=jU9_wV2KfJM:1
# Skipping invalid term line: https://www.youtube.com/watch?v=nqFpfrUrMM4:1
# Skipping invalid term line: https://www.youtube.com/watch?v=tRg_eDfQ8fk:1
# Skipping invalid term line: https://www.zoho.com/crm/help/customization/related-lists.html:1
# Skipping invalid term line: https://www14.software.ibm.com/webapp/iwm/web/preLogin.do?source=dka&S_PKG=aix64j7r1&S_TACT=105AGX05&S_CMP=JDK:1
# Skipping invalid term line: https://xiph.org/vorbis/doc/vorbisfile/ov_open.html:1
# Skipping invalid term line: https://xsom.java.net/:1
# Skipping invalid term line: https://youtrack.jetbrains.com/issue/IDEA-81620:1
# Skipping invalid term line: https://youtrack.jetbrains.com/issue/IDEABKL-6460:1
# Skipping invalid term line: https://youtrack.jetbrains.com/issue/WEB-14045#comment=27-846895:1
# Skipping invalid term line: https://youtrack.jetbrains.com/issue/WEB-14060:1
# Skipping invalid term line: https://{accountname}.cloudant.com/{dbname}/_design/acralyzer/index.html:1
# c:\Users\annie\anaconda3\anaconda\Lib\site-packages\transformers\utils\generic.py:260: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# c:\Users\annie\anaconda3\anaconda\Lib\site-packages\transformers\modeling_utils.py:479: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(checkpoint_file, map_location=map_location)
# Processing batches: 100%|██████████| 847/847 [22:37<00:00,  1.60s/it]
# "106A" ['"RENUKA"', '"mraa"', '"monsters2"', '"voyage88"', '"0987654321"']
# "1089" ['"011110000100101"', '"0987654321"', '"monsters2"', '"monsters1"', '"RENUKA"']
# "109" ['"WEBSITE"', '"WSANSWER"', '"old_school"', '"dokuman"', '"WhiteOne"']
# "10D" ['"dokuman"', '"multiOption2"', '"equalSpacing"', '"PivotStyle1"', '"monsters2"']
# "10MB" ['"monsters1"', '"explain2"', '"sqlite3"', '"monsters2"', '"myCarousel2"']
# "10dp" ['"monsters2"', '"vivek"', '"dokuman"', '"monsters1"', '"droppable"']
# "10xyz" ['1921489Z"', '"0b0101__101"', '"myCarousel2"', '"011110000100101"', '"prime239v3"']
# "11" ['"blah1"', '"blah3"', '"monsters1"', '"sqlite3"', '"mraa"']
# "112 ['"sound4"', '"rd1Orange"', '"sound1"', '"rd1Pink"', '"rd1Female"']
# "11447_en ['"parallelogramAreaBase"', 'pi_m4th_root', '"dt_rateio_inicial"', '"dt_rateio_final"', '"odincategory38"']

# %%
word = list(vocab)[100]  # Convert dict_keys to a list

print(word)
similar_words = find_similar_words(word, vocab_embeddings, word_list)
print(f"Top words similar to '{word}':")
for w, score in similar_words:
    print(f"{w}: {score:.4f}")
# Out:
# account
# Top words similar to 'account':
# account: 0.9851
# activetab: 0.9842
# table_nam: 0.9836
# ifram: 0.9833
# updatelayout: 0.9832

# %%
index = {
    "example": {
        "df": 2,
        "doc_info": {
            "doc1": [5, 15, 30],  # Token "example" appears 3 times in doc1
            "doc2": [7, 25]       # Token "example" appears 2 times in doc2
        }
    },
    "query": {
        "df": 1,
        "doc_info": {
            "doc2": [10]          # Token "query" appears 1 time in doc2
        }
    }
}

    # Document lengths (total tokens per document)
doc_lengths = {
        "doc1": 100,  # Document 1 has 100 tokens
        "doc2": 150   # Document 2 has 150 tokens
    }
vocab = ["example", "query"]

    # Define the query string
query = "example query"

    # Perform retrieval
results = retrieval_function(query, index, doc_lengths)

    # Print results
print("Top Results:", results)
# Out:
# Top Results: [('doc2', 0.8806417664214886), ('doc1', 0.3198623803402712)]

# %%
#load the index given
inverted_index_positions = {}

with open("index.txt", 'r', encoding='utf-8', errors='replace') as file:
    current_term = None
    for line in file:
        line = line.rstrip()  # Remove trailing whitespace
        
        if not line:  # Skip blank lines
            continue
        
        if not line.startswith("\t"):  # A new term with its document frequency
            # Check if the line contains a valid term:df pair
            if ":" in line:
                term, df = line.split(":", 1)  # Split only on the first ":"
                current_term = term.strip()
                try:
                    inverted_index_positions[current_term] = {'df': int(df.strip()), 'doc_info': []}
                except ValueError:
                    print(f"Skipping invalid term line: {line}")
                    current_term = None
        elif current_term:  # Document information under the current term
            # Check if the line starts with a valid docno
            if ":" in line.strip("\t"):
                doc_info = line.strip("\t")  # Remove the tab
                try:
                    docno, positions_str = doc_info.split(":", 1)
                    positions = list(map(int, positions_str.split(",")))  # Convert positions to integers
                    inverted_index_positions[current_term]['doc_info'].append((docno.strip(), positions))
                except ValueError:
                    print(f"Skipping invalid doc_info line: {line}")
# Out:
# Skipping invalid term line: http://blog.whatsapp.com/index.php/2011/09/one-million/":64
# Skipping invalid term line: http://blogs.msdn.com/b/webdev/archive/2012/09/26/workaround-for-html-closing-tag-problem.aspx":13
# Skipping invalid term line: http://blogs.msdn.com/b/webdev/archive/2012/09/26/workaround-for-html-closing-tag-problem.aspx</a></p>:13
# Skipping invalid term line: http://chaicode-3lads.rhcloud.com/":33
# Skipping invalid term line: http://docs.oracle.com/javafx/2/api/javafx/scene/web/webengine.html":15
# Skipping invalid term line: http://docs.oracle.com/javafx/2/api/javafx/scene/web/webengine.html</a></p>:15
# Skipping invalid term line: http://docs.oracle.com/javase/1.4.2/docs/api/java/lang/integer.html#parseint(java.lang.string":46
# Skipping invalid term line: http://docs.oracle.com/javase/1.4.2/docs/api/java/lang/integer.html#parseint(java.lang.string</a>)</p>:46
# Skipping invalid term line: http://github.com/zeusdeux/chaicode":33
# Skipping invalid term line: http://headjs.com/":2
# Skipping invalid term line: http://itunes.apple.com/linkmaker/":60
# Skipping invalid term line: http://itunes.apple.com/linkmaker/</a></p>:60
# Skipping invalid term line: http://jsfiddle.net/dwfg6/4/":42
# Skipping invalid term line: http://jsfiddle.net/dwfg6/4/</a></p>:42
# Skipping invalid term line: http://mfi.apple.com/faqs":21
# Skipping invalid term line: http://msdn.microsoft.com/en-us/library/system.runtime.serialization.json.datacontractjsonserializer.aspx":19
# Skipping invalid term line: http://php.net/manual/en/function.pfsockopen.php":43
# Skipping invalid term line: http://schemas.android.com/apk/res/android":51
# Skipping invalid term line: http://www.mathworks.com/products/neural-network/webinars.html":57
# Skipping invalid term line: http://www.mathworks.com/products/neural-network/webinars.html</a></p>:57
# Skipping invalid term line: http://www.process-one.net/en/ejabberd/":64
# Skipping invalid term line: http://www.rabbitmq.com":64
# Skipping invalid term line: https://developer.apple.com/library/mac/#documentation/cocoa/reference/foundation/classes/nsstring_class/reference/nsstring.html":35
# Skipping invalid term line: https://developer.apple.com/library/mac/#documentation/cocoa/reference/foundation/classes/nsstring_class/reference/nsstring.html</a></p>:35
# Skipping invalid term line: https://i.stack.imgur.com/juatb.png":3
# Skipping invalid term line: https://i.stack.imgur.com/ntf1t.png":1
# Skipping invalid term line: https://i.stack.imgur.com/vxqfp.png":31
# Skipping invalid term line: https://stackoverflow.com/a/510225">https://stackoverflow.com/a/510225</a></p>:24
# Skipping invalid term line: https://stackoverflow.com/questions/2132370/android-listview-getscrolly-does-it-work">android::16
# Skipping invalid term line: https://stackoverflow.com/questions/5734071/looking-for-experiences-on-the-apple-mfi-program-registration-process">thi:21

# %%
vocab = inverted_index_positions.keys()

# %%
#build L2R
